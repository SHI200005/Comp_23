# %%
import matplotlib.pyplot as plt

T_serial = 325.135
T_2 = 201.109
T_3 = 145.473
T_5 = 114.204
T_9 = 105.793
T_16 = 112.486

P = [2,3,5,9,16]
S = [T_serial/T_2,T_serial/T_3,T_serial/T_5,T_serial/T_9,T_serial/T_16]

plt.plot(P,S,'x')
plt.xlim(0,18)
plt.xlable('P')
plt.ylabel('S')
# Out:
# (0.0, 18.0)
